# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    # features: 2
    distance = np.sum((feature-center)**2, axis=1)
    distance = np.sqrt(distance)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    same_label = (label_feature == label)
    parsed_feature = feature[same_label]
    if(np.size(parsed_feature, 0) == 0):
        return None

    centroid = np.mean(parsed_feature, axis=0)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    label_feature = np.argmin(distance, axis=1)
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %%
def compute_loss(distance, label_feature, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    parsed_distance = distance[np.arange(len(distance)), label_feature]
    loss_sum = np.power(parsed_distance, 2)
    loss = np.sum(loss_sum) / len(feature)
  
    return loss

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 5000     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

for i in range(number_iteration):
      # shape [1000, 2]
      distance_iteration_02 = np.zeros((number_data, number_cluster))
      for j in range(number_cluster):
            cur_centroid = compute_centroid(feature, label_feature_02, j)
            if(cur_centroid is None):
                  centroid_iteration_02[i, j] = centroid_iteration_02[i-1, j]
            else:
                  centroid_iteration_02[i, j] = cur_centroid
            distance_iteration_02[:, j] = compute_distance(feature, centroid_iteration_02[i, j])
      label_feature_02 = compute_label(distance_iteration_02)
      loss_iteration_02[i] = compute_loss(distance_iteration_02, label_feature_02, feature)

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 5000    # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

for i in range(number_iteration):
      distance_iteration_04 = np.zeros((number_data, number_cluster))
      for j in range(number_cluster):
            cur_centroid = compute_centroid(feature, label_feature_04, j)
            if(cur_centroid is None):
                  centroid_iteration_04[i, j] = centroid_iteration_04[i-1, j]
            else:
                  centroid_iteration_04[i, j] = cur_centroid
            distance_iteration_04[:, j] = compute_distance(feature, centroid_iteration_04[i, j])
      label_feature_04 = compute_label(distance_iteration_04)
      loss_iteration_04[i] = compute_loss(distance_iteration_04, label_feature_04, feature)

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 12000     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

for i in range(number_iteration):
      distance_iteration_08 = np.zeros((number_data, number_cluster))
      for j in range(number_cluster):
            cur_centroid = compute_centroid(feature, label_feature_08, j)
            if(cur_centroid is None):
                  centroid_iteration_08[i, j] = centroid_iteration_08[i-1, j]
            else:
                  centroid_iteration_08[i, j] = cur_centroid
            distance_iteration_08[:, j] = compute_distance(feature, centroid_iteration_08[i, j])
      label_feature_08 = compute_label(distance_iteration_08)
      loss_iteration_08[i] = compute_loss(distance_iteration_08, label_feature_08, feature)

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 50000     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

for i in range(number_iteration):
      distance_iteration_16 = np.zeros((number_data, number_cluster))
      for j in range(number_cluster):
            cur_centroid = compute_centroid(feature, label_feature_16, j)
            if(cur_centroid is None):
                  centroid_iteration_16[i, j] = centroid_iteration_16[i-1, j]
            else:
                  centroid_iteration_16[i, j] = cur_centroid
            distance_iteration_16[:, j] = compute_distance(feature, centroid_iteration_16[i, j])
      label_feature_16 = compute_label(distance_iteration_16)
      loss_iteration_16[i] = compute_loss(distance_iteration_16, label_feature_16, feature)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    colors = ['purple', 'orange']

    for i in range(2):
        plt.plot(centroid_iteration_02[:,i,0],centroid_iteration_02[:,i,1],'-', color=colors[i], label="cluster="+str(i))

    plt.plot(centroid_iteration_02[0,:,0],centroid_iteration_02[0,:,1],'o', color="red", label="initial")
    plt.plot(centroid_iteration_02[-1,:,0],centroid_iteration_02[-1,:,1],'s', color="blue", label="final")
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    colors = ['purple', 'orange', 'green', 'blue']
    for i in range(4):
        plt.plot(centroid_iteration_04[:,i,0],centroid_iteration_04[:,i,1],'-', color=colors[i], label="cluster="+str(i))
    
    plt.plot(centroid_iteration_04[0,:,0],centroid_iteration_04[0,:,1],'o', color="red", label="initial")
    plt.plot(centroid_iteration_04[-1,:,0],centroid_iteration_04[-1,:,1],'s', color="blue", label="final")

    plt.legend()
    plt.tight_layout()
    plt.show()
    

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    colors = ['purple', 'orange', 'green', 'blue', 'brown', 'pink', 'yellow', 'grey']
    for i in range(8):
        plt.plot(centroid_iteration_08[:,i,0],centroid_iteration_08[:,i,1],'-', color=colors[i], label="cluster="+str(i))
    
    plt.plot(centroid_iteration_08[0,:,0],centroid_iteration_08[0,:,1],'o', color="red", label="initial")
    plt.plot(centroid_iteration_08[-1,:,0],centroid_iteration_08[-1,:,1],'s', color="blue", label="final")

    plt.legend()
    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    colors = ['purple', 'orange', 'green', 'blue', 'brown', 'pink', 'yellow', 'grey', 'black', 'white', 'red', 'green', 'blue', 'yellow', 'pink', 'grey', 'brown']
    for i in range(16):
        plt.plot(centroid_iteration_16[:,i,0],centroid_iteration_16[:,i,1],'-', color=colors[i], label="cluster="+str(i))
    
    plt.plot(centroid_iteration_16[0,:,0],centroid_iteration_16[0,:,1],'o', color="red", label="initial")
    plt.plot(centroid_iteration_16[-1,:,0],centroid_iteration_16[-1,:,1],'s', color="blue", label="final")

    plt.legend()
    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    cmap = plt.get_cmap('viridis', 2)
    ax = plt.subplot()

    for i in range(2):
        ax.plot(x[label_feature_02 == i], y[label_feature_02 == i], 'o', color=cmap(i), label="cluster="+str(i))

    scalar_cmap = cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=2))
    scalar_cmap.set_array([])

    plt.colorbar(scalar_cmap, ticks=np.linspace(0, 1, 2))
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    cmap = plt.get_cmap('viridis', 4)
    ax = plt.subplot()

    for i in range(4):
        ax.plot(x[label_feature_04 == i], y[label_feature_04 == i], 'o', color=cmap(i), label="cluster="+str(i))

    scalar_cmap = cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=4))
    scalar_cmap.set_array([])

    plt.colorbar(scalar_cmap, ticks=np.linspace(0, 1, 4))
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    cmap = plt.get_cmap('viridis', 8)
    ax = plt.subplot()

    for i in range(8):
        ax.plot(x[label_feature_08 == i], y[label_feature_08 == i], 'o', color=cmap(i), label="cluster="+str(i))

    scalar_cmap = cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=8))
    scalar_cmap.set_array([])
    
    plt.colorbar(scalar_cmap, ticks=np.linspace(0, 1, 8))
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    cmap = plt.get_cmap('viridis', 16)
    ax = plt.subplot()

    for i in range(16):
        ax.plot(x[label_feature_16 == i], y[label_feature_16 == i], 'o', color=cmap(i), label="cluster="+str(i))

    scalar_cmap = cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=16))
    scalar_cmap.set_array([])

    plt.colorbar(scalar_cmap, ticks=np.linspace(0, 1, 16))
    plt.legend()
    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1126288111
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  5.6822562719
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.3741256507
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# ...
